# %%
# %matplotlib inline
from event import Event, iet
import matplotlib.pyplot as plt
import numpy as np
# Out:
# number of events detected: (1975, 7)

# %%
e = Event(id=1000)
e.plot('waveforms')
# Out:
# (<Figure size 1080x2160 with 12 Axes>,
#  array([<AxesSubplot:ylabel='Pressure (Pa)'>,
#         <AxesSubplot:ylabel='Pressure (Pa)'>,
#         <AxesSubplot:ylabel='Pressure (Pa)'>,
#         <AxesSubplot:ylabel='Pressure (Pa)'>,
#         <AxesSubplot:ylabel='Pressure (Pa)'>,
#         <AxesSubplot:ylabel='Pressure (Pa)'>], dtype=object))

# %%
e.depth
# Out:
# 412.2

# %%
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.plot(e750.aics[3])
# ax2 = ax.twinx()
# ax2.plot(np.diff(e750.aics[3]), color='red')

# diffmax = np.argmax(np.diff(e750.aics[3], n=1))
# ax.plot([diffmax,diffmax], [-1000, 4500], color='limegreen')
# ax.plot(e750.stream[3].data, color='black')
# diffmax

# %%
# e750.plot('waveforms')
