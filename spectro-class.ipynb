# %%
from Event import Event
import torchaudio.transforms as T
import librosa
import torch

import matplotlib.dates as mdates
import datetime

from pvel_util import *

# %%
df141 = import_catalog(file='141precision.csv')

# %%
plot_event(event_id=1499, day_number=141, df=df141)
# Out:
# 197 0.03496335396468406
# (501,)
